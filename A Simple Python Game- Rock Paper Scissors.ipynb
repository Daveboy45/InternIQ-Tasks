# %%
import random

choices = ["Rock",'Paper','Scissors']
                  
def main():
    comp = 0
    play = 0
    print("Rock--Paper--Scissors\U0001F3B2")
    
    click= input("Press ENTER to play the game")
    name = input("Input your name\n")
    print()
    while True:
        print("1)5 Entries\n2)7 Entries\n3)9 Entries\n4)Exit\n")
        mode= int(input("Select the game mode\n"))
        if mode  == 1:
            comp= 0
            play = 0
            while True:
                player = input("Rock,Paper or Scissors?: ")
                computer = random.choice(choices)
            
                if player.title() not in choices:
                    print('Invalid selection')
                    pass
                if player.lower() == computer.lower():
                    print('Computer: ',computer)
                    print("Player: ",player)
                    print("Tie")
                    comp += 0
                    play += 0 
                elif player.lower() == 'rock':
                    if computer.lower() == 'paper':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You lose")
                        comp += 1
                        play += 0
                    elif computer.lower() == 'scissors':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Win")
                        comp += 0
                        play += 1
                elif player.lower() == 'scissors':
                    if computer.lower() == 'paper':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You win")
                        comp += 0
                        play += 1
                    elif computer.lower() == 'rock':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Lose")
                        comp += 1
                        play += 0
            
                elif player.lower() == 'paper':
                    if computer.lower() == 'scissors':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Lose")
                        comp += 1
                        play += 0
                    elif computer.lower() == 'rock':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Win")
                        comp += 0
                        play += 1
                        
                if comp + play == 5:
                    print("\nComputer:" , comp)
                    print(f"{name}: {play}")
                    if comp > play:
                        print("Computer wins\U0001F3C6\n")
                        break
                    elif play > comp:
                        print(f"{name} wins\U0001F3C6\n")
                        break
                        
                
        if mode  == 2:
            comp= 0
            play = 0
            while True:
                player = input("Rock,Paper or Scissors?: ")
                computer = random.choice(choices)
            
                if player.title() not in choices:
                    print('Invalid selection')
                    pass
                if player.lower() == computer.lower():
                    print('Computer: ',computer)
                    print("Player: ",player)
                    print("Tie")
                    comp += 0
                    play += 0 
                elif player.lower() == 'rock':
                    if computer.lower() == 'paper':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You lose")
                        comp += 1
                        play += 0
                    elif computer.lower() == 'scissors':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Win")
                        comp += 0
                        play += 1
                elif player.lower() == 'scissors':
                    if computer.lower() == 'paper':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You win")
                        comp += 0
                        play += 1
                    elif computer.lower() == 'rock':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Lose")
                        comp += 1
                        play += 0
            
                elif player.lower() == 'paper':
                    if computer.lower() == 'scissors':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Lose")
                        comp += 1
                        play += 0
                    elif computer.lower() == 'rock':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Win")
                        comp += 0
                        play += 1
                        
                if comp + play == 7:
                    print("\nComputer:" , comp)
                    print(f"{name}: {play}")
                    if comp > play:
                        print("Computer wins\U0001F3C6\n")
                        break
                    elif play > comp:
                        print(f"{name} wins\U0001F3C6\n")
                        break
        if mode  == 3:
            comp= 0
            play = 0
            while True:
                player = input("Rock,Paper or Scissors?: ")
                computer = random.choice(choices)
            
                if player.title() not in choices:
                    print('Invalid selection')
                    pass
                if player.lower() == computer.lower():
                    print('Computer: ',computer)
                    print("Player: ",player)
                    print("Tie")
                    comp += 0
                    play += 0 
                elif player.lower() == 'rock':
                    if computer.lower() == 'paper':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You lose")
                        comp += 1
                        play += 0
                    elif computer.lower() == 'scissors':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Win")
                        comp += 0
                        play += 1
                elif player.lower() == 'scissors':
                    if computer.lower() == 'paper':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You win")
                        comp += 0
                        play += 1
                    elif computer.lower() == 'rock':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Lose")
                        comp += 1
                        play += 0
            
                elif player.lower() == 'paper':
                    if computer.lower() == 'scissors':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Lose")
                        comp += 1
                        play += 0
                    elif computer.lower() == 'rock':
                        print('Computer: ',computer)
                        print("Player: ",player)
                        print("You Win")
                        comp += 0
                        play += 1
                        
                if comp + play == 9:
                    print("\nComputer:" , comp)
                    print(f"{name}: {play}")
                    if comp > play:
                        print("Computer wins\U0001F3C6\n")
                        break
                    elif play > comp:
                        print(f"{name} wins\U0001F3C6\n")
                        break
        if mode == 4:
            print("---Exiting Application---")
            break
                          
                
                        
main()
# Out:
# Rock--Paper--Scissors🎲
# Press ENTER to play the game
# Input your name
# David
#
# 1)5 Entries
# 2)7 Entries
# 3)9 Entries
# 4)Exit
#
# Select the game mode
# 1
# Rock,Paper or Scissors?: Rock
# Computer:  Scissors
# Player:  Rock
# You Win
# Rock,Paper or Scissors?: Paper
# Computer:  Scissors
# Player:  Paper
# You Lose
# Rock,Paper or Scissors?: rock
# Computer:  Scissors
# Player:  rock
# You Win
# Rock,Paper or Scissors?: scissors
# Computer:  Scissors
# Player:  scissors
# Tie
# Rock,Paper or Scissors?: rock
# Computer:  Paper
# Player:  rock
# You lose
# Rock,Paper or Scissors?: rock
# Computer:  Rock
# Player:  rock
# Tie
# Rock,Paper or Scissors?: paper
# Computer:  Rock
# Player:  paper
# You Win
#
# Computer: 2
# David: 3
# David wins🏆
#
# 1)5 Entries
# 2)7 Entries
# 3)9 Entries
# 4)Exit
#
# Select the game mode
# 4
# ---Exiting Application---
